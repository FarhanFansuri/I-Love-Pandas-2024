# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanFansuri/I-Love-Pandas-2024/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setting konfigurasi

# %%
pd.set_option('display.max_columns',85)

# %% [markdown]
# ### Import data

# %%
df = pd.read_csv('./survey_results_public.csv')
schema_df = pd.read_csv('./survey_results_schema.csv')

# %%
# Buat dictionary dengan data pengguna
data_user = {
    "user1": {
        "nama": "John Doe",
        "umur": 30,
        "alamat": "Jl. Merdeka No. 10",
        "email": "john.doe@example.com"
    },
    "user2": {
        "nama": "Jane Smith",
        "umur": 25,
        "alamat": "Jl. Pahlawan No. 5",
        "email": "jane.smith@example.com"
    },
    "user3": {
        "nama": "Bob Johnson",
        "umur": 40,
        "alamat": "Jl. Kebon Sirih No. 15",
        "email": "bob.johnson@example.com"
    }
}

# Buat DataFrame dari dictionary data_user
df_data = pd.DataFrame(data_user).T  # .T digunakan untuk melakukan transpose agar index menjadi nama pengguna

# %%
# Tampilkan jumlah series pada DataFrame
df_data.count(0)
# Out:
# nama      3
# umur      3
# alamat    3
# email     3
# dtype: int64

# %%
df_data[['nama','umur']]
# Out:
#               nama umur
# user1     John Doe   30
# user2   Jane Smith   25
# user3  Bob Johnson   40

# %%
# menampilkan data kolom
df_data.columns
# Out:
# Index(['nama', 'umur', 'alamat', 'email'], dtype='object')

# %%
# menampilkan data baris
# iloc , integer location
df_data.iloc[[0,2]]

print(df_data.iloc[[0,2],[0,1]])
# Out:
#               nama umur
# user1     John Doe   30
# user3  Bob Johnson   40

# %%
# menampilkan data baris
# loc
df_data.loc[["user1","user2"]]
# Out:
#              nama umur              alamat                   email
# user1    John Doe   30  Jl. Merdeka No. 10    john.doe@example.com
# user2  Jane Smith   25  Jl. Pahlawan No. 5  jane.smith@example.com

# %%
# menampilkan jumlah nilai
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# menampilkan baris
# df.loc[range(0,10),"Hobbyist"]
df.loc[0:3,"Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time

# %%
df_data.index
# Out:
# Index(['user1', 'user2', 'user3'], dtype='object')

# %%
# set and sort index
df_data.set_index('email',inplace=True)
df_data.sort_index()
# Out:
#                                 nama umur                  alamat
# email
# bob.johnson@example.com  Bob Johnson   40  Jl. Kebon Sirih No. 15
# jane.smith@example.com    Jane Smith   25      Jl. Pahlawan No. 5
# john.doe@example.com        John Doe   30      Jl. Merdeka No. 10

# %%
df_data.reset_index(inplace=True)
df_data.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
